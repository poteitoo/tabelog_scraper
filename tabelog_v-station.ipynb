# %%
import re
import time

import pandas as pd
import requests
from bs4 import BeautifulSoup


class Tabelog:
    """
    食べログスクレイピングクラス
    test_mode=Trueで動作させると、最初のページの３店舗のデータのみを取得できる
    """
    def __init__(self, base_url, category, test_mode=False, p_ward='東京都内', begin_page=1, end_page=1, do_save_everytime=False):

        # 変数宣言
        self.store_id = ''
        self.store_id_num = 0
        self.store_name = ''
        self.score = 0
        self.score_detail = ''
        self.ward = p_ward
        self.review_cnt = 0
        self.review = ''
        self.user_info = ''
        self.columns = ['store_id', 'store_name', 'score', 'ward', 'review_cnt', 'review', 'user_info', 'score_detail']
        self.df = pd.DataFrame(columns=self.columns)
        self.__regexcomp = re.compile(r'\n|\s') # \nは改行、\sは空白
        self.do_save_everytime = do_save_everytime
        self.count_to_save = 0
        self.category = category

        page_num = begin_page # 店舗一覧ページ番号

        if test_mode:
            # list_url = base_url + str(page_num) +  '/?Srt=D&SrtT=rt&sort_mode=1' #食べログの点数ランキングでソートする際に必要な処理
            list_url = base_url+ str(page_num) + '/?svd=20201104&svt=1900&svps=2'
            self.scrape_list(list_url, mode=test_mode)
        else:
            while True:
                list_url = base_url
                # list_url = base_url + str(page_num) +  '/?Srt=D&SrtT=rt&sort_mode=1' #食べログの点数ランキングでソートする際に必要な処理
                if self.scrape_list(list_url, mode=test_mode) != True:
                    break

                # INパラメータまでのページ数データを取得する
                if page_num >= end_page:
                    break
                page_num += 1
        return

    def scrape_list(self, list_url, mode):
        """
        店舗一覧ページのパーシング
        """
        r = requests.get(list_url)
        if r.status_code != requests.codes.ok:
            return False

        soup = BeautifulSoup(r.content, 'html.parser')
        soup_a_list = soup.find_all('a', class_='list-rst__rst-name-target') # 店名一覧

        if len(soup_a_list) == 0:
            return False

        if mode:
            for soup_a in soup_a_list[:2]:
                item_url = soup_a.get('href') # 店の個別ページURLを取得
                self.store_id_num += 1
                self.scrape_item(item_url, mode)
        else:
            for soup_a in soup_a_list:
                item_url = soup_a.get('href') # 店の個別ページURLを取得
                self.store_id_num += 1
                self.scrape_item(item_url, mode)

        return True

    def scrape_item(self, item_url, mode):
        """
        個別店舗情報ページのパーシング
        """
        start = time.time()

        r = requests.get(item_url)
        if r.status_code != requests.codes.ok:
            print(f'error:not found{ item_url }')
            return

        soup = BeautifulSoup(r.content, 'html.parser')

        # 店舗名称取得
        # <h2 class="display-name">
        #     <span>
        #         麺匠　竹虎 新宿店
        #     </span>
        # </h2>
        store_name_tag = soup.find('h2', class_='display-name')
        store_name = store_name_tag.span.string
        print('{}→店名：{}'.format(self.store_id_num, store_name.strip()), end='')
        self.store_name = store_name.strip()

        # ラーメン屋、つけ麺屋以外の店舗は除外
        store_head = soup.find('div', class_='rdheader-subinfo') # 店舗情報のヘッダー枠データ取得
        store_head_list = store_head.find_all('dl')
        store_head_list = store_head_list[1].find_all('span')
        #print('ターゲット：', store_head_list[0].text)

        # if store_head_list[0].text not in {'ラーメン', 'つけ麺'}:
        #     print('ラーメンorつけ麺のお店ではないので処理対象外')
        #     self.store_id_num -= 1
        #     return

        # 評価点数取得
        #<b class="c-rating__val rdheader-rating__score-val" rel="v:rating">
        #    <span class="rdheader-rating__score-val-dtl">3.58</span>
        #</b>
        rating_score_tag = soup.find('b', class_='c-rating__val')
        rating_score = rating_score_tag.span.string
        print('  評価点数：{}点'.format(rating_score), end='')
        self.score = rating_score

        # 評価点数が存在しない店舗は除外
        if rating_score == '-':
            print('  評価がないため処理対象外')
            self.store_id_num -= 1
            return
       # 評価が3.5未満店舗は除外
    #     if float(rating_score) < 3.5:
    #         print('  食べログ評価が3.5未満のため処理対象外')
    #         self.store_id_num -= 1
    #         return

        # レビュー一覧URL取得
        #<a class="mainnavi" href="https://tabelog.com/tokyo/A1304/A130401/13143442/dtlrvwlst/"><span>口コミ</span><span class="rstdtl-navi__total-count"><em>60</em></span></a>
        review_tag_id = soup.find('li', id="rdnavi-review")
        review_tag = review_tag_id.a.get('href')

        # レビュー件数取得
        print('  レビュー件数：{}'.format(review_tag_id.find('span', class_='rstdtl-navi__total-count').em.string), end='')
        self.review_cnt = review_tag_id.find('span', class_='rstdtl-navi__total-count').em.string

        # レビュー一覧ページ番号
        page_num = 1 #1ページ*20 = 20レビュー 。この数字を変えて取得するレビュー数を調整。

        # レビュー一覧ページから個別レビューページを読み込み、パーシング
        # 店舗の全レビューを取得すると、食べログの評価ごとにデータ件数の濃淡が発生してしまうため、
        # 取得するレビュー数は１ページ分としている（件数としては１ページ*20=２0レビュー）
        while True:
            review_url = review_tag + 'COND-0/smp1/?lc=0&rvw_part=all&PG=' + str(page_num)
            #print('\t口コミ一覧リンク：{}'.format(review_url))
            print(' . ' , end='') #LOG
            if self.scrape_review(review_url) != True:
                break
            if page_num >= 1:
                break
            page_num += 1

        process_time = time.time() - start
        print('  取得時間：{}'.format(process_time))

        return

    def scrape_review(self, review_url):
        """
        レビュー一覧ページのパーシング
        """
        r = requests.get(review_url)
        if r.status_code != requests.codes.ok:
            print(f'error:not found{ review_url }')
            return False

        # 各個人の口コミページ詳細へのリンクを取得する
        #<div class="rvw-item js-rvw-item-clickable-area" data-detail-url="/tokyo/A1304/A130401/13141542/dtlrvwlst/B408082636/?use_type=0&amp;smp=1">
        #</div>
        soup = BeautifulSoup(r.content, 'html.parser')
        review_url_list = soup.find_all('div', class_='rvw-item') # 口コミ詳細ページURL一覧

        if len(review_url_list) == 0:
            return False

        for url in review_url_list:
            review_detail_url = 'https://tabelog.com' + url.get('data-detail-url')
            #print('\t口コミURL：', review_detail_url)

            # 口コミのテキストを取得
            self.get_review_text(review_detail_url)

        return True

    def get_review_text(self, review_detail_url):
        """
        口コミ詳細ページをパーシング
        """
        r = requests.get(review_detail_url)
        if r.status_code != requests.codes.ok:
            print(f'error:not found{ review_detail_url }')
            return

        # ２回以上来訪してコメントしているユーザは最新の1件のみを採用
        #<div class="rvw-item__rvw-comment" property="v:description">
        #  <p>
        #    <br>すごい煮干しラーメン凪 新宿ゴールデン街本館<br>スーパーゴールデン1600円（20食限定）を喰らう<br>大盛り無料です<br>スーパーゴールデンは、新宿ゴールデン街にちなんで、ココ本店だけの特別メニューだそうです<br>相方と歌舞伎町のtohoシネマズの映画館でドラゴンボール超ブロリー を観てきた<br>ブロリー 強すぎるね(^^)面白かったです<br>凪の煮干しラーメンも激ウマ<br>いったん麺ちゅるちゅる感に、レアチャーと大トロチャーシューのトロけ具合もうめえ<br>煮干しスープもさすが！と言うほど完成度が高い<br>さすが食べログラーメン百名店<br>と言うか<br>2日連チャンで、近場の食べログラーメン百名店のうちの2店舗、昨日の中華そば葉山さんと今日の凪<br>静岡では考えられん笑笑<br>ごちそうさまでした
        #  </p>
        #</div>
        soup = BeautifulSoup(r.content, 'html.parser')
        review = soup.find_all('div', class_='rvw-item__rvw-comment')#reviewが含まれているタグの中身をすべて取得
        if len(review) == 0:
            review = ''
        else:
            review = review[0].p.text.strip() # strip()は改行コードを除外する関数

        #print('\t\t口コミテキスト：', review)
        self.review = review
        
        info = soup.find_all('span', class_='rvw-item__rvwr-profile')
        if len(info) == 0:
            info = ''
        else:
            info = info[0].text

        self.user_info = info

        score = soup.find_all('li', class_='rvw-item__single-ratings-item')
        if len(score) == 0:
            score = ''
        else:
            score = score[0].text

        self.score_detail = score

        # データフレームの生成
        self.make_df()
        return

    def make_df(self):
        self.count_to_save += 1

        self.store_id = str(self.store_id_num).zfill(8) #0パディング
        se = pd.Series([self.store_id, self.store_name, self.score, self.ward, self.review_cnt, self.review, self.user_info, self.score_detail], self.columns) # 行を作成
        self.df = self.df.append(se, self.columns) # データフレームに行を追加
        if self.do_save_everytime and self.count_to_save > 10:
            self.df.to_csv(f'temp_{self.category }.csv')
            self.count_to_save = 0
        return

if __name__ == "__main__":
    stations = ["toranomon", "meidai-mae", "yurakucho", 'hiyoshi']
    url_station = [
        "https://tabelog.com/tokyo/A1308/A130802/R6877/rstLst/",
        "https://tabelog.com/tokyo/A1318/A131804/R9953/rstLst/",
        "https://tabelog.com/tokyo/A1301/A130102/R10345/rstLst/",
        "https://tabelog.com/kanagawa/A1401/A140204/R8547/rstLst/",
    ]
    for station, s_urls in zip(stations, url_station):
        tokyo_ramen_review = Tabelog(
            base_url=s_urls,
            test_mode=False,
            p_ward=station,
            end_page=6,
            do_save_everytime=True,
            category=station,
        )
        tokyo_ramen_review.df.to_csv(
            f"./Tabelog_station_data/tokyo_{station}_review.csv"
        )
# Out:
# 1→店名：IRISH PUB CELTS 新橋日比谷口店  評価点数：3.01点  レビュー件数：4 .   取得時間：5.055361270904541
# 2→店名：和食バル 音音 虎ノ門ヒルズ店  評価点数：3.25点  レビュー件数：52 .   取得時間：23.606717586517334
# 3→店名：炭火焼鳥とまぐろ食べ放題 全席個室 鳥江戸こまち 新橋店  評価点数：3.10点  レビュー件数：9 .   取得時間：10.02838683128357
# 4→店名：上海風情  評価点数：3.38点  レビュー件数：29 .   取得時間：19.347705125808716
# 5→店名：響 風庭 赤坂店  評価点数：3.22点  レビュー件数：66 .   取得時間：21.040765047073364
# 6→店名：cafe&dining ballo ballo 虎ノ門  評価点数：3.19点  レビュー件数：15 .   取得時間：14.396298170089722
# 7→店名：新橋 沖縄料理 奄美料理 島の台所 まさむぬ  評価点数：3.08点  レビュー件数：6 .   取得時間：6.831656455993652
# 8→店名：木曽路  評価点数：3.11点  レビュー件数：7 .   取得時間：6.745252370834351
# 9→店名：ElTragón  評価点数：3.45点  レビュー件数：39 .   取得時間：23.83899164199829
# 10→店名：カンティーナ  評価点数：3.36点  レビュー件数：26 .   取得時間：19.783488988876343
# 11→店名：マルサラ by 三笠バル  評価点数：3.26点  レビュー件数：44 .   取得時間：19.818986654281616
# 12→店名：すしざんまい 新橋ＳＬ広場前店  評価点数：3.23点  レビュー件数：91 .   取得時間：20.79728102684021
# 13→店名：ジンギスカン霧島 新橋店  評価点数：3.20点  レビュー件数：58 .   取得時間：19.454129695892334
# 14→店名：個室＆ビアガーデン和牛ステーキ食べ放題 六喜 新橋店  評価点数：3.02点  レビュー件数：1 .   取得時間：2.229018449783325
# 15→店名：プラチナフィッシュ クラフトビアバル  評価点数：3.43点  レビュー件数：34 .   取得時間：23.99414300918579
# 16→店名：完全個室 天鮨 新橋本店  評価点数：3.34点  レビュー件数：76 .   取得時間：20.075218200683594
# 17→店名：おりんち  評価点数：3.42点  レビュー件数：27 .   取得時間：20.39396047592163
# 18→店名：リザラン 新橋店  評価点数：3.25点  レビュー件数：54 .   取得時間：19.787055492401123
# 19→店名：カスピタ 新橋  評価点数：3.43点  レビュー件数：55 .   取得時間：19.547414541244507
# 20→店名：オステリア パージナ  評価点数：3.58点  レビュー件数：110 .   取得時間：23.140862941741943
# 21→店名：IRISH PUB CELTS 新橋日比谷口店  評価点数：3.01点  レビュー件数：4 .   取得時間：5.149688959121704
# 22→店名：和食バル 音音 虎ノ門ヒルズ店  評価点数：3.25点  レビュー件数：52 .   取得時間：20.29452681541443
# 23→店名：炭火焼鳥とまぐろ食べ放題 全席個室 鳥江戸こまち 新橋店  評価点数：3.10点  レビュー件数：9 .   取得時間：9.916313409805298
# 24→店名：上海風情  評価点数：3.38点  レビュー件数：29 .   取得時間：19.026611804962158
# 25→店名：響 風庭 赤坂店  評価点数：3.22点  レビュー件数：66 .   取得時間：21.1086745262146
# 26→店名：cafe&dining ballo ballo 虎ノ門  評価点数：3.19点  レビュー件数：15 .   取得時間：14.748780250549316
# 27→店名：新橋 沖縄料理 奄美料理 島の台所 まさむぬ  評価点数：3.08点  レビュー件数：6 .   取得時間：8.873738050460815
# 28→店名：木曽路  評価点数：3.11点  レビュー件数：7 .   取得時間：7.232546329498291
# 29→店名：ElTragón  評価点数：3.45点  レビュー件数：39 .   取得時間：22.008776664733887
# 30→店名：カンティーナ  評価点数：3.36点  レビュー件数：26 .   取得時間：18.90799856185913
# 31→店名：マルサラ by 三笠バル  評価点数：3.26点  レビュー件数：44 .   取得時間：19.351965188980103
# 32→店名：すしざんまい 新橋ＳＬ広場前店  評価点数：3.23点  レビュー件数：91 .   取得時間：21.31532597541809
# 33→店名：ジンギスカン霧島 新橋店  評価点数：3.20点  レビュー件数：58 .   取得時間：20.914273977279663
# 34→店名：個室＆ビアガーデン和牛ステーキ食べ放題 六喜 新橋店  評価点数：3.02点  レビュー件数：1 .   取得時間：2.5198071002960205
# 35→店名：プラチナフィッシュ クラフトビアバル  評価点数：3.43点  レビュー件数：34 .   取得時間：20.635338068008423
# 36→店名：完全個室 天鮨 新橋本店  評価点数：3.34点  レビュー件数：76 .   取得時間：20.18352437019348
# 37→店名：おりんち  評価点数：3.42点  レビュー件数：27 .   取得時間：18.67043662071228
# 38→店名：リザラン 新橋店  評価点数：3.25点  レビュー件数：54 .   取得時間：18.975531578063965
# 39→店名：カスピタ 新橋  評価点数：3.43点  レビュー件数：55 .   取得時間：20.001724004745483
# 40→店名：オステリア パージナ  評価点数：3.58点  レビュー件数：110 .   取得時間：24.700387001037598
# 41→店名：IRISH PUB CELTS 新橋日比谷口店  評価点数：3.01点  レビュー件数：4 .   取得時間：4.84735631942749
# 42→店名：和食バル 音音 虎ノ門ヒルズ店  評価点数：3.25点  レビュー件数：52 .   取得時間：19.406148672103882
# 43→店名：炭火焼鳥とまぐろ食べ放題 全席個室 鳥江戸こまち 新橋店  評価点数：3.10点  レビュー件数：9 .   取得時間：9.99347734451294
# 44→店名：上海風情  評価点数：3.38点  レビュー件数：29 .   取得時間：18.750110387802124
# 45→店名：響 風庭 赤坂店  評価点数：3.22点  レビュー件数：66 .   取得時間：22.09983539581299
# 46→店名：cafe&dining ballo ballo 虎ノ門  評価点数：3.19点  レビュー件数：15 .   取得時間：15.405623197555542
# 47→店名：新橋 沖縄料理 奄美料理 島の台所 まさむぬ  評価点数：3.08点  レビュー件数：6 .   取得時間：9.00663161277771
# 48→店名：木曽路  評価点数：3.11点  レビュー件数：7 .   取得時間：7.276823997497559
# 49→店名：ElTragón  評価点数：3.45点  レビュー件数：39 .   取得時間：22.501489877700806
# 50→店名：カンティーナ  評価点数：3.36点  レビュー件数：26 .   取得時間：19.638448238372803
# 51→店名：マルサラ by 三笠バル  評価点数：3.26点  レビュー件数：44 .   取得時間：20.39431357383728
# 52→店名：すしざんまい 新橋ＳＬ広場前店  評価点数：3.23点  レビュー件数：91 .   取得時間：21.540426015853882
# 53→店名：ジンギスカン霧島 新橋店  評価点数：3.20点  レビュー件数：58 .   取得時間：19.2456271648407
# 54→店名：個室＆ビアガーデン和牛ステーキ食べ放題 六喜 新橋店  評価点数：3.02点  レビュー件数：1 .   取得時間：4.958331823348999
# 55→店名：プラチナフィッシュ クラフトビアバル  評価点数：3.43点  レビュー件数：34 .   取得時間：21.923604488372803
# 56→店名：完全個室 天鮨 新橋本店  評価点数：3.34点  レビュー件数：76 .   取得時間：19.867074012756348
# 57→店名：おりんち  評価点数：3.42点  レビュー件数：27 .   取得時間：19.65164875984192
# 58→店名：リザラン 新橋店  評価点数：3.25点  レビュー件数：54 .   取得時間：19.131417989730835
# 59→店名：カスピタ 新橋  評価点数：3.43点  レビュー件数：55 .   取得時間：19.77956485748291
# 60→店名：オステリア パージナ  評価点数：3.58点  レビュー件数：110 .   取得時間：23.319875240325928
# 61→店名：IRISH PUB CELTS 新橋日比谷口店  評価点数：3.01点  レビュー件数：4 .   取得時間：5.173497200012207
# 62→店名：和食バル 音音 虎ノ門ヒルズ店  評価点数：3.25点  レビュー件数：52 .   取得時間：19.084446907043457
# 63→店名：炭火焼鳥とまぐろ食べ放題 全席個室 鳥江戸こまち 新橋店  評価点数：3.10点  レビュー件数：9 .   取得時間：14.214963436126709
# 64→店名：上海風情  評価点数：3.38点  レビュー件数：29 .   取得時間：19.127054691314697
# 65→店名：響 風庭 赤坂店  評価点数：3.22点  レビュー件数：66 .   取得時間：21.836605548858643
# 66→店名：cafe&dining ballo ballo 虎ノ門  評価点数：3.19点  レビュー件数：15 .   取得時間：14.95557427406311
# 67→店名：新橋 沖縄料理 奄美料理 島の台所 まさむぬ  評価点数：3.08点  レビュー件数：6 .   取得時間：6.985079765319824
# 68→店名：木曽路  評価点数：3.11点  レビュー件数：7 .   取得時間：7.184252738952637
# 69→店名：ElTragón  評価点数：3.45点  レビュー件数：39 .   取得時間：23.901023387908936
# 70→店名：カンティーナ  評価点数：3.36点  レビュー件数：26 .   取得時間：19.939435243606567
# 71→店名：マルサラ by 三笠バル  評価点数：3.26点  レビュー件数：44 .   取得時間：20.688905239105225
# 72→店名：すしざんまい 新橋ＳＬ広場前店  評価点数：3.23点  レビュー件数：91 .   取得時間：21.86586618423462
# 73→店名：ジンギスカン霧島 新橋店  評価点数：3.20点  レビュー件数：58 .   取得時間：19.487234592437744
# 74→店名：個室＆ビアガーデン和牛ステーキ食べ放題 六喜 新橋店  評価点数：3.02点  レビュー件数：1 .   取得時間：2.8363077640533447
# 75→店名：プラチナフィッシュ クラフトビアバル  評価点数：3.43点  レビュー件数：34 .   取得時間：24.519349813461304
# 76→店名：完全個室 天鮨 新橋本店  評価点数：3.34点  レビュー件数：76 .   取得時間：20.632110357284546
# 77→店名：おりんち  評価点数：3.42点  レビュー件数：27 .   取得時間：19.94097876548767
# 78→店名：リザラン 新橋店  評価点数：3.25点  レビュー件数：54 .   取得時間：20.76727867126465
# 79→店名：カスピタ 新橋  評価点数：3.43点  レビュー件数：55 .   取得時間：19.48655939102173
# 80→店名：オステリア パージナ  評価点数：3.58点  レビュー件数：110 .   取得時間：22.363476037979126
# 81→店名：IRISH PUB CELTS 新橋日比谷口店  評価点数：3.01点  レビュー件数：4 .   取得時間：5.180572748184204
# 82→店名：和食バル 音音 虎ノ門ヒルズ店  評価点数：3.25点  レビュー件数：52 .   取得時間：21.81031084060669
# 83→店名：炭火焼鳥とまぐろ食べ放題 全席個室 鳥江戸こまち 新橋店  評価点数：3.10点  レビュー件数：9 .   取得時間：9.854674100875854
# 84→店名：上海風情  評価点数：3.38点  レビュー件数：29 .   取得時間：19.06294870376587
# 85→店名：響 風庭 赤坂店  評価点数：3.22点  レビュー件数：66 .   取得時間：21.635262966156006
# 86→店名：cafe&dining ballo ballo 虎ノ門  評価点数：3.19点  レビュー件数：15 .   取得時間：14.965711832046509
# 87→店名：新橋 沖縄料理 奄美料理 島の台所 まさむぬ  評価点数：3.08点  レビュー件数：6 .   取得時間：7.18403172492981
# 88→店名：木曽路  評価点数：3.11点  レビュー件数：7 .   取得時間：7.25109076499939
# 89→店名：ElTragón  評価点数：3.45点  レビュー件数：39 .   取得時間：23.9096040725708
# 90→店名：カンティーナ  評価点数：3.36点  レビュー件数：26 .   取得時間：21.913533926010132
# 91→店名：マルサラ by 三笠バル  評価点数：3.26点  レビュー件数：44 .   取得時間：20.658745288848877
# 92→店名：すしざんまい 新橋ＳＬ広場前店  評価点数：3.23点  レビュー件数：91 .   取得時間：22.085705518722534
# 93→店名：ジンギスカン霧島 新橋店  評価点数：3.20点  レビュー件数：58 .   取得時間：20.292898893356323
# 94→店名：個室＆ビアガーデン和牛ステーキ食べ放題 六喜 新橋店  評価点数：3.02点  レビュー件数：1 .   取得時間：2.7275314331054688
# 95→店名：プラチナフィッシュ クラフトビアバル  評価点数：3.43点  レビュー件数：34 .   取得時間：21.44050884246826
# 96→店名：完全個室 天鮨 新橋本店  評価点数：3.34点  レビュー件数：76 .   取得時間：20.483338356018066
# 97→店名：おりんち  評価点数：3.42点  レビュー件数：27 .   取得時間：23.413952350616455
# 98→店名：リザラン 新橋店  評価点数：3.25点  レビュー件数：54 .   取得時間：19.60282802581787
# 99→店名：カスピタ 新橋  評価点数：3.43点  レビュー件数：55 .   取得時間：20.112228870391846
# 100→店名：オステリア パージナ  評価点数：3.58点  レビュー件数：110 .   取得時間：22.072930812835693
# 101→店名：IRISH PUB CELTS 新橋日比谷口店  評価点数：3.01点  レビュー件数：4 .   取得時間：5.362609386444092
# 102→店名：和食バル 音音 虎ノ門ヒルズ店  評価点数：3.25点  レビュー件数：52 .   取得時間：19.930249214172363
# 103→店名：炭火焼鳥とまぐろ食べ放題 全席個室 鳥江戸こまち 新橋店  評価点数：3.10点  レビュー件数：9 .   取得時間：9.505961418151855
# 104→店名：上海風情  評価点数：3.38点  レビュー件数：29 .   取得時間：18.818941831588745
# 105→店名：響 風庭 赤坂店  評価点数：3.22点  レビュー件数：66 .   取得時間：23.994235038757324
# 106→店名：cafe&dining ballo ballo 虎ノ門  評価点数：3.19点  レビュー件数：15 .   取得時間：15.286194324493408
# 107→店名：新橋 沖縄料理 奄美料理 島の台所 まさむぬ  評価点数：3.08点  レビュー件数：6 .   取得時間：7.025068521499634
# 108→店名：木曽路  評価点数：3.11点  レビュー件数：7 .   取得時間：7.783515691757202
# 109→店名：ElTragón  評価点数：3.45点  レビュー件数：39 .   取得時間：21.3325514793396
# 110→店名：カンティーナ  評価点数：3.36点  レビュー件数：26 .   取得時間：19.693097591400146
# 111→店名：マルサラ by 三笠バル  評価点数：3.26点  レビュー件数：44 .   取得時間：20.265541076660156
# 112→店名：すしざんまい 新橋ＳＬ広場前店  評価点数：3.23点  レビュー件数：91 .   取得時間：23.840776443481445
# 113→店名：ジンギスカン霧島 新橋店  評価点数：3.20点  レビュー件数：58 .   取得時間：19.487244606018066
# 114→店名：個室＆ビアガーデン和牛ステーキ食べ放題 六喜 新橋店  評価点数：3.02点  レビュー件数：1 .   取得時間：2.184394121170044
# 115→店名：プラチナフィッシュ クラフトビアバル  評価点数：3.43点  レビュー件数：34 .   取得時間：20.3017737865448
# 116→店名：完全個室 天鮨 新橋本店  評価点数：3.34点  レビュー件数：76 .   取得時間：19.844947576522827
# 117→店名：おりんち  評価点数：3.42点  レビュー件数：27 .   取得時間：19.648767232894897
# 118→店名：リザラン 新橋店  評価点数：3.25点  レビュー件数：54 .   取得時間：19.563953399658203
# 119→店名：カスピタ 新橋  評価点数：3.43点  レビュー件数：55 .   取得時間：19.351457118988037
# 120→店名：オステリア パージナ  評価点数：3.58点  レビュー件数：110 .   取得時間：24.58369731903076
# 1→店名：居酒屋 NIJYU-MARU 明大前店  評価点数：3.00点  レビュー件数：6 .   取得時間：6.861123323440552
# 2→店名：大江戸ホルモン 明大前店  評価点数：3.07点  レビュー件数：6 .   取得時間：6.216536521911621
# 3→店名：ととや 東松原  評価点数：3.08点  レビュー件数：8 .   取得時間：8.741420984268188
# 4→店名：魚売街  評価点数：-点  評価がないため処理対象外
# 4→店名：8PLACE The Kitchen ＆ Bar 明大前  評価点数：3.00点  レビュー件数：1 .   取得時間：2.009587287902832
# 5→店名：はちいち   明大前店  評価点数：3.21点  レビュー件数：8 .   取得時間：7.985831260681152
# 6→店名：炭火焼鳥 串善 明大前店  評価点数：3.11点  レビュー件数：6 .   取得時間：5.533552408218384
# 7→店名：アジアン屋台 チャオサイゴンパリバール  評価点数：3.04点  レビュー件数：2 .   取得時間：3.467637062072754
# 8→店名：明大前 肉流通センター  評価点数：3.08点  レビュー件数：7 .   取得時間：7.375727415084839
# 9→店名：やきとり家すみれ 明大前店  評価点数：3.07点  レビュー件数：23 .   取得時間：21.57156538963318
# 10→店名：シーズレシピ  評価点数：3.02点  レビュー件数：1 .   取得時間：1.941871166229248
# 11→店名：かくれん坊  評価点数：3.09点  レビュー件数：7 .   取得時間：6.4493982791900635
# 12→店名：宮古2号店 宮古島の伝統料理  評価点数：3.21点  レビュー件数：14 .   取得時間：12.415103912353516
# 13→店名：はんばあぐはうす ぐずぐず  評価点数：3.40点  レビュー件数：30 .   取得時間：23.764005184173584
# 14→店名：盛華らーめん  評価点数：3.14点  レビュー件数：23 .   取得時間：19.00726294517517
# 15→店名：とんこつラーメン博多風龍 明大前店  評価点数：3.02点  レビュー件数：13 .   取得時間：11.652382612228394
# 16→店名：もみじ屋  評価点数：3.48点  レビュー件数：94 .   取得時間：20.492385149002075
# 17→店名：近江家  評価点数：3.23点  レビュー件数：18 .   取得時間：16.330440282821655
# 18→店名：ソウル苑  評価点数：3.44点  レビュー件数：36 .   取得時間：21.64668297767639
# 19→店名：ときそば  評価点数：3.25点  レビュー件数：22 .   取得時間：21.474411249160767
# 20→店名：居酒屋 NIJYU-MARU 明大前店  評価点数：3.00点  レビュー件数：6 .   取得時間：6.861238241195679
# 21→店名：大江戸ホルモン 明大前店  評価点数：3.07点  レビュー件数：6 .   取得時間：5.829730749130249
# 22→店名：ととや 東松原  評価点数：3.08点  レビュー件数：8 .   取得時間：8.184285402297974
# 23→店名：魚売街  評価点数：-点  評価がないため処理対象外
# 23→店名：8PLACE The Kitchen ＆ Bar 明大前  評価点数：3.00点  レビュー件数：1 .   取得時間：1.9131906032562256
# 24→店名：はちいち   明大前店  評価点数：3.21点  レビュー件数：8 .   取得時間：8.05005168914795
# 25→店名：炭火焼鳥 串善 明大前店  評価点数：3.11点  レビュー件数：6 .   取得時間：6.2718284130096436
# 26→店名：アジアン屋台 チャオサイゴンパリバール  評価点数：3.04点  レビュー件数：2 .   取得時間：3.5152463912963867
# 27→店名：明大前 肉流通センター  評価点数：3.08点  レビュー件数：7 .   取得時間：7.5867533683776855
# 28→店名：やきとり家すみれ 明大前店  評価点数：3.07点  レビュー件数：23 .   取得時間：22.02958631515503
# 29→店名：シーズレシピ  評価点数：3.02点  レビュー件数：1 .   取得時間：1.897108554840088
# 30→店名：かくれん坊  評価点数：3.09点  レビュー件数：7 .   取得時間：5.997847557067871
# 31→店名：宮古2号店 宮古島の伝統料理  評価点数：3.21点  レビュー件数：14 .   取得時間：12.60751748085022
# 32→店名：はんばあぐはうす ぐずぐず  評価点数：3.40点  レビュー件数：30 .   取得時間：20.90175151824951
# 33→店名：盛華らーめん  評価点数：3.14点  レビュー件数：23 .   取得時間：19.305551290512085
# 34→店名：とんこつラーメン博多風龍 明大前店  評価点数：3.02点  レビュー件数：13 .   取得時間：11.888903379440308
# 35→店名：もみじ屋  評価点数：3.48点  レビュー件数：94 .   取得時間：21.72145390510559
# 36→店名：近江家  評価点数：3.23点  レビュー件数：18 .   取得時間：15.415390729904175
# 37→店名：ソウル苑  評価点数：3.44点  レビュー件数：36 .   取得時間：18.454622268676758
# 38→店名：ときそば  評価点数：3.25点  レビュー件数：22 .   取得時間：20.433847188949585
# 39→店名：居酒屋 NIJYU-MARU 明大前店  評価点数：3.00点  レビュー件数：6 .   取得時間：7.124753713607788
# 40→店名：大江戸ホルモン 明大前店  評価点数：3.07点  レビュー件数：6 .   取得時間：5.951274156570435
# 41→店名：ととや 東松原  評価点数：3.08点  レビュー件数：8 .   取得時間：10.423162460327148
# 42→店名：魚売街  評価点数：-点  評価がないため処理対象外
# 42→店名：8PLACE The Kitchen ＆ Bar 明大前  評価点数：3.00点  レビュー件数：1 .   取得時間：2.106151580810547
# 43→店名：はちいち   明大前店  評価点数：3.21点  レビュー件数：8 .   取得時間：8.041881799697876
# 44→店名：炭火焼鳥 串善 明大前店  評価点数：3.11点  レビュー件数：6 .   取得時間：5.877293586730957
# 45→店名：アジアン屋台 チャオサイゴンパリバール  評価点数：3.04点  レビュー件数：2 .   取得時間：3.467003107070923
# 46→店名：明大前 肉流通センター  評価点数：3.08点  レビュー件数：7 .   取得時間：7.696361064910889
# 47→店名：やきとり家すみれ 明大前店  評価点数：3.07点  レビュー件数：23 .   取得時間：21.151641845703125
# 48→店名：シーズレシピ  評価点数：3.02点  レビュー件数：1 .   取得時間：1.8961679935455322
# 49→店名：かくれん坊  評価点数：3.09点  レビュー件数：7 .   取得時間：6.428556203842163
# 50→店名：宮古2号店 宮古島の伝統料理  評価点数：3.21点  レビュー件数：14 .   取得時間：12.675091743469238
# 51→店名：はんばあぐはうす ぐずぐず  評価点数：3.40点  レビュー件数：30 .   取得時間：20.359501361846924
# 52→店名：盛華らーめん  評価点数：3.14点  レビュー件数：23 .   取得時間：20.344492435455322
# 53→店名：とんこつラーメン博多風龍 明大前店  評価点数：3.02点  レビュー件数：13 .   取得時間：12.408640623092651
# 54→店名：もみじ屋  評価点数：3.48点  レビュー件数：94 .   取得時間：19.031851291656494
# 55→店名：近江家  評価点数：3.23点  レビュー件数：18 .   取得時間：16.573179483413696
# 56→店名：ソウル苑  評価点数：3.44点  レビュー件数：36 .   取得時間：19.244340181350708
# 57→店名：ときそば  評価点数：3.25点  レビュー件数：22 .   取得時間：22.60712695121765
# 58→店名：居酒屋 NIJYU-MARU 明大前店  評価点数：3.00点  レビュー件数：6 .   取得時間：6.712588548660278
# 59→店名：大江戸ホルモン 明大前店  評価点数：3.07点  レビュー件数：6 .   取得時間：6.173810958862305
# 60→店名：ととや 東松原  評価点数：3.08点  レビュー件数：8 .   取得時間：8.511279344558716
# 61→店名：魚売街  評価点数：-点  評価がないため処理対象外
# 61→店名：8PLACE The Kitchen ＆ Bar 明大前  評価点数：3.00点  レビュー件数：1 .   取得時間：1.8370857238769531
# 62→店名：はちいち   明大前店  評価点数：3.21点  レビュー件数：8 .   取得時間：7.922258615493774
# 63→店名：炭火焼鳥 串善 明大前店  評価点数：3.11点  レビュー件数：6 .   取得時間：5.687832832336426
# 64→店名：アジアン屋台 チャオサイゴンパリバール  評価点数：3.04点  レビュー件数：2 .   取得時間：3.350843906402588
# 65→店名：明大前 肉流通センター  評価点数：3.08点  レビュー件数：7 .   取得時間：7.77592658996582
# 66→店名：やきとり家すみれ 明大前店  評価点数：3.07点  レビュー件数：23 .   取得時間：20.141804456710815
# 67→店名：シーズレシピ  評価点数：3.02点  レビュー件数：1 .   取得時間：1.87296724319458
# 68→店名：かくれん坊  評価点数：3.09点  レビュー件数：7 .   取得時間：6.187016010284424
# 69→店名：宮古2号店 宮古島の伝統料理  評価点数：3.21点  レビュー件数：14 .   取得時間：14.969557285308838
# 70→店名：はんばあぐはうす ぐずぐず  評価点数：3.40点  レビュー件数：30 .   取得時間：18.78171443939209
# 71→店名：盛華らーめん  評価点数：3.14点  レビュー件数：23 .   取得時間：18.6169695854187
# 72→店名：とんこつラーメン博多風龍 明大前店  評価点数：3.02点  レビュー件数：13 .   取得時間：11.32581877708435
# 73→店名：もみじ屋  評価点数：3.48点  レビュー件数：94 .   取得時間：20.337985038757324
# 74→店名：近江家  評価点数：3.23点  レビュー件数：18 .   取得時間：18.50613307952881
# 75→店名：ソウル苑  評価点数：3.44点  レビュー件数：36 .   取得時間：19.2117338180542
# 76→店名：ときそば  評価点数：3.25点  レビュー件数：22 .   取得時間：19.784231901168823
# 77→店名：居酒屋 NIJYU-MARU 明大前店  評価点数：3.00点  レビュー件数：6 .   取得時間：6.856473207473755
# 78→店名：大江戸ホルモン 明大前店  評価点数：3.07点  レビュー件数：6 .   取得時間：5.915163516998291
# 79→店名：ととや 東松原  評価点数：3.08点  レビュー件数：8 .   取得時間：8.363372802734375
# 80→店名：魚売街  評価点数：-点  評価がないため処理対象外
# 80→店名：8PLACE The Kitchen ＆ Bar 明大前  評価点数：3.00点  レビュー件数：1 .   取得時間：2.1918883323669434
# 81→店名：はちいち   明大前店  評価点数：3.21点  レビュー件数：8 .   取得時間：7.559301853179932
# 82→店名：炭火焼鳥 串善 明大前店  評価点数：3.11点  レビュー件数：6 .   取得時間：6.246966600418091
# 83→店名：アジアン屋台 チャオサイゴンパリバール  評価点数：3.04点  レビュー件数：2 .   取得時間：3.4922714233398438
# 84→店名：明大前 肉流通センター  評価点数：3.08点  レビュー件数：7 .   取得時間：7.817566394805908
# 85→店名：やきとり家すみれ 明大前店  評価点数：3.07点  レビュー件数：23 .   取得時間：23.241499662399292
# 86→店名：シーズレシピ  評価点数：3.02点  レビュー件数：1 .   取得時間：2.003774404525757
# 87→店名：かくれん坊  評価点数：3.09点  レビュー件数：7 .   取得時間：6.645764589309692
# 88→店名：宮古2号店 宮古島の伝統料理  評価点数：3.21点  レビュー件数：14 .   取得時間：12.173170328140259
# 89→店名：はんばあぐはうす ぐずぐず  評価点数：3.40点  レビュー件数：30 .   取得時間：20.041226387023926
# 90→店名：盛華らーめん  評価点数：3.14点  レビュー件数：23 .   取得時間：18.946666955947876
# 91→店名：とんこつラーメン博多風龍 明大前店  評価点数：3.02点  レビュー件数：13 .   取得時間：12.124696731567383
# 92→店名：もみじ屋  評価点数：3.48点  レビュー件数：94 .   取得時間：21.524993658065796
# 93→店名：近江家  評価点数：3.23点  レビュー件数：18 .   取得時間：16.091460704803467
# 94→店名：ソウル苑  評価点数：3.44点  レビュー件数：36 .   取得時間：18.86576223373413
# 95→店名：ときそば  評価点数：3.25点  レビュー件数：22 .   取得時間：21.71975064277649
# 96→店名：居酒屋 NIJYU-MARU 明大前店  評価点数：3.00点  レビュー件数：6 .   取得時間：6.732499122619629
# 97→店名：大江戸ホルモン 明大前店  評価点数：3.07点  レビュー件数：6 .   取得時間：5.74932074546814
# 98→店名：ととや 東松原  評価点数：3.08点  レビュー件数：8 .   取得時間：8.38314437866211
# 99→店名：魚売街  評価点数：-点  評価がないため処理対象外
# 99→店名：8PLACE The Kitchen ＆ Bar 明大前  評価点数：3.00点  レビュー件数：1 .   取得時間：2.312426805496216
# 100→店名：はちいち   明大前店  評価点数：3.21点  レビュー件数：8 .   取得時間：7.801670551300049
# 101→店名：炭火焼鳥 串善 明大前店  評価点数：3.11点  レビュー件数：6 .   取得時間：7.700587749481201
# 102→店名：アジアン屋台 チャオサイゴンパリバール  評価点数：3.04点  レビュー件数：2 .   取得時間：3.6075823307037354
# 103→店名：明大前 肉流通センター  評価点数：3.08点  レビュー件数：7 .   取得時間：7.154798984527588
# 104→店名：やきとり家すみれ 明大前店  評価点数：3.07点  レビュー件数：23 .   取得時間：21.385481357574463
# 105→店名：シーズレシピ  評価点数：3.02点  レビュー件数：1 .   取得時間：2.489807367324829
# 106→店名：かくれん坊  評価点数：3.09点  レビュー件数：7 .   取得時間：6.251409530639648
# 107→店名：宮古2号店 宮古島の伝統料理  評価点数：3.21点  レビュー件数：14 .   取得時間：12.7958824634552
# 108→店名：はんばあぐはうす ぐずぐず  評価点数：3.40点  レビュー件数：30 .   取得時間：19.974825859069824
# 109→店名：盛華らーめん  評価点数：3.14点  レビュー件数：23 .   取得時間：18.207698822021484
# 114→店名：ときそば  評価点数：3.25点  レビュー件数：22 .   取得時間：20.3606173992157
# 1→店名：アルカナ 東京  評価点数：3.57点  レビュー件数：102 .   取得時間：22.949066400527954
# 2→店名：花大根  評価点数：3.45点  レビュー件数：81 .   取得時間：25.22028946876526
# 3→店名：プーケットオリエンタル  評価点数：3.41点  レビュー件数：88 .   取得時間：18.07331085205078
# 4→店名：銀座 水炊きと焼き鳥 笹二  評価点数：3.25点  レビュー件数：45 .   取得時間：20.1893310546875
# 5→店名：アクアリウムダイニング銀座ライム  評価点数：3.47点  レビュー件数：129 .   取得時間：32.30117392539978
# 6→店名：鉄板焼　銀明翠 銀座  評価点数：3.37点  レビュー件数：34 .   取得時間：56.46618366241455
# 7→店名：東京 今井屋本店  評価点数：3.55点  レビュー件数：144 .   取得時間：29.810319662094116
# 8→店名：すし縁  評価点数：3.54点  レビュー件数：77 .   取得時間：26.920382499694824
# 9→店名：オイスターバー&ワイン BELON 銀座  評価点数：3.44点  レビュー件数：48 .   取得時間：25.696725368499756
# 10→店名：しゃぶしゃぶ　すき鍋　おもき 銀座店  評価点数：3.30点  レビュー件数：95 .   取得時間：26.51058030128479
# 11→店名：塊 -KATAMARI- ミートバル 銀座  評価点数：3.25点  レビュー件数：56 .   取得時間：21.752567768096924
# 12→店名：京都 瓢喜 京橋店  評価点数：3.21点  レビュー件数：53 .   取得時間：22.049049139022827
# 13→店名：リストランテ･ヒロ・チェントロ 丸ビル店  評価点数：3.72点  レビュー件数：268 .   取得時間：24.457632780075073
# 14→店名：鮨たかや  評価点数：3.64点  レビュー件数：47 .   取得時間：21.437409162521362
# 15→店名：GRANBLANC  評価点数：3.36点  レビュー件数：63 .   取得時間：23.474370002746582
# 16→店名：小割烹 おはし 銀座  評価点数：3.41点  レビュー件数：43 .   取得時間：22.280830144882202
# 17→店名：PLUSTOKYO ROOFTOP  評価点数：-点  評価がないため処理対象外
# 17→店名：ラムしゃぶ 金の目 銀座本店  評価点数：3.58点  レビュー件数：140 .   取得時間：22.958937644958496
# 18→店名：PLUSTOKYO  評価点数：3.18点  レビュー件数：10 .   取得時間：10.385368585586548
# 19→店名：個室居酒屋 鳥助 有楽町店  評価点数：-点  評価がないため処理対象外
# 19→店名：アルカナ 東京  評価点数：3.57点  レビュー件数：102 .   取得時間：24.066955089569092
# 20→店名：花大根  評価点数：3.45点  レビュー件数：81 .   取得時間：22.167144060134888
# 21→店名：プーケットオリエンタル  評価点数：3.41点  レビュー件数：88 .   取得時間：20.80024290084839
# 22→店名：銀座 水炊きと焼き鳥 笹二  評価点数：3.25点  レビュー件数：45 .   取得時間：18.86937689781189
# 23→店名：アクアリウムダイニング銀座ライム  評価点数：3.47点  レビュー件数：129 .   取得時間：22.02733325958252
# 24→店名：鉄板焼　銀明翠 銀座  評価点数：3.37点  レビュー件数：34 .   取得時間：20.634061336517334
# 25→店名：東京 今井屋本店  評価点数：3.55点  レビュー件数：144 .   取得時間：22.23282027244568
# 26→店名：すし縁  評価点数：3.54点  レビュー件数：77 .   取得時間：21.642354011535645
# 27→店名：オイスターバー&ワイン BELON 銀座  評価点数：3.44点  レビュー件数：48 .   取得時間：20.982928037643433
# 28→店名：しゃぶしゃぶ　すき鍋　おもき 銀座店  評価点数：3.30点  レビュー件数：95 .   取得時間：23.987101078033447
# 29→店名：塊 -KATAMARI- ミートバル 銀座  評価点数：3.25点  レビュー件数：56 .   取得時間：21.503721714019775
# 30→店名：京都 瓢喜 京橋店  評価点数：3.21点  レビュー件数：53 .   取得時間：20.788551092147827
# 31→店名：リストランテ･ヒロ・チェントロ 丸ビル店  評価点数：3.72点  レビュー件数：268 .   取得時間：23.018823623657227
# 32→店名：鮨たかや  評価点数：3.64点  レビュー件数：47 .   取得時間：21.84681725502014
# 33→店名：GRANBLANC  評価点数：3.36点  レビュー件数：63 .   取得時間：21.292905569076538
# 34→店名：小割烹 おはし 銀座  評価点数：3.41点  レビュー件数：43 .   取得時間：21.453850030899048
# 35→店名：PLUSTOKYO ROOFTOP  評価点数：-点  評価がないため処理対象外
# 35→店名：ラムしゃぶ 金の目 銀座本店  評価点数：3.58点  レビュー件数：140 .   取得時間：21.07803440093994
# 36→店名：PLUSTOKYO  評価点数：3.18点  レビュー件数：10 .   取得時間：9.693100214004517
# 37→店名：個室居酒屋 鳥助 有楽町店  評価点数：-点  評価がないため処理対象外
# 37→店名：アルカナ 東京  評価点数：3.57点  レビュー件数：102 .   取得時間：22.959585428237915
# 38→店名：花大根  評価点数：3.45点  レビュー件数：81 .   取得時間：21.150159120559692
# 39→店名：プーケットオリエンタル  評価点数：3.41点  レビュー件数：88 .   取得時間：19.893133878707886
# 40→店名：銀座 水炊きと焼き鳥 笹二  評価点数：3.25点  レビュー件数：45 .   取得時間：19.75780725479126
# 41→店名：アクアリウムダイニング銀座ライム  評価点数：3.47点  レビュー件数：129 .   取得時間：26.7538001537323
# 42→店名：鉄板焼　銀明翠 銀座  評価点数：3.37点  レビュー件数：34 .   取得時間：20.239860773086548
# 43→店名：東京 今井屋本店  評価点数：3.55点  レビュー件数：144 .   取得時間：22.482394695281982
# 44→店名：すし縁  評価点数：3.54点  レビュー件数：77 .   取得時間：20.940004348754883
# 45→店名：オイスターバー&ワイン BELON 銀座  評価点数：3.44点  レビュー件数：48 .   取得時間：21.851910829544067
# 46→店名：しゃぶしゃぶ　すき鍋　おもき 銀座店  評価点数：3.30点  レビュー件数：95 .   取得時間：22.1301748752594
# 47→店名：塊 -KATAMARI- ミートバル 銀座  評価点数：3.25点  レビュー件数：56 .   取得時間：22.732735633850098
# 48→店名：京都 瓢喜 京橋店  評価点数：3.21点  レビュー件数：53 .   取得時間：20.709319829940796
# 49→店名：リストランテ･ヒロ・チェントロ 丸ビル店  評価点数：3.72点  レビュー件数：268 .   取得時間：22.50941562652588
# 50→店名：鮨たかや  評価点数：3.64点  レビュー件数：47 .   取得時間：20.980282068252563
# 51→店名：GRANBLANC  評価点数：3.36点  レビュー件数：63 .   取得時間：23.435217142105103
# 52→店名：小割烹 おはし 銀座  評価点数：3.41点  レビュー件数：43 .   取得時間：21.374086141586304
# 53→店名：PLUSTOKYO ROOFTOP  評価点数：-点  評価がないため処理対象外
# 53→店名：ラムしゃぶ 金の目 銀座本店  評価点数：3.58点  レビュー件数：140 .   取得時間：21.19148588180542
# 54→店名：PLUSTOKYO  評価点数：3.18点  レビュー件数：10 .   取得時間：10.691546201705933
# 55→店名：個室居酒屋 鳥助 有楽町店  評価点数：-点  評価がないため処理対象外
# 55→店名：アルカナ 東京  評価点数：3.57点  レビュー件数：102 .   取得時間：21.960562467575073
# 56→店名：花大根  評価点数：3.45点  レビュー件数：81 .   取得時間：22.708393335342407
# 57→店名：プーケットオリエンタル  評価点数：3.41点  レビュー件数：88 .   取得時間：19.325195789337158
# 58→店名：銀座 水炊きと焼き鳥 笹二  評価点数：3.25点  レビュー件数：45 .   取得時間：20.297080516815186
# 59→店名：アクアリウムダイニング銀座ライム  評価点数：3.47点  レビュー件数：129 .   取得時間：21.61405658721924
# 60→店名：鉄板焼　銀明翠 銀座  評価点数：3.37点  レビュー件数：34 .   取得時間：19.3050274848938
# 61→店名：東京 今井屋本店  評価点数：3.55点  レビュー件数：144 .   取得時間：23.697641849517822
# 62→店名：すし縁  評価点数：3.54点  レビュー件数：77 .   取得時間：21.396963596343994
# 63→店名：オイスターバー&ワイン BELON 銀座  評価点数：3.44点  レビュー件数：48 .   取得時間：21.07323908805847
# 64→店名：しゃぶしゃぶ　すき鍋　おもき 銀座店  評価点数：3.30点  レビュー件数：95 .   取得時間：22.72272515296936
# 65→店名：塊 -KATAMARI- ミートバル 銀座  評価点数：3.25点  レビュー件数：56 .   取得時間：20.08908176422119
# 66→店名：京都 瓢喜 京橋店  評価点数：3.21点  レビュー件数：53 .   取得時間：23.274766445159912
# 67→店名：リストランテ･ヒロ・チェントロ 丸ビル店  評価点数：3.72点  レビュー件数：268 .   取得時間：22.710734605789185
# 68→店名：鮨たかや  評価点数：3.64点  レビュー件数：47 .   取得時間：19.74898076057434
# 69→店名：GRANBLANC  評価点数：3.36点  レビュー件数：63 .   取得時間：20.342902660369873
# 70→店名：小割烹 おはし 銀座  評価点数：3.41点  レビュー件数：43 .   取得時間：21.227381467819214
# 71→店名：PLUSTOKYO ROOFTOP  評価点数：-点  評価がないため処理対象外
# 71→店名：ラムしゃぶ 金の目 銀座本店  評価点数：3.58点  レビュー件数：140 .   取得時間：22.709234952926636
# 72→店名：PLUSTOKYO  評価点数：3.18点  レビュー件数：10 .   取得時間：10.690101623535156
# 73→店名：個室居酒屋 鳥助 有楽町店  評価点数：-点  評価がないため処理対象外
# 73→店名：アルカナ 東京  評価点数：3.57点  レビュー件数：102 .   取得時間：21.249611139297485
# 74→店名：花大根  評価点数：3.45点  レビュー件数：81 .   取得時間：20.409202814102173
# 75→店名：プーケットオリエンタル  評価点数：3.41点  レビュー件数：88 .   取得時間：19.50828194618225
# 76→店名：銀座 水炊きと焼き鳥 笹二  評価点数：3.25点  レビュー件数：45 .   取得時間：21.798187017440796
# 77→店名：アクアリウムダイニング銀座ライム  評価点数：3.47点  レビュー件数：129 .   取得時間：20.82197070121765
# 78→店名：鉄板焼　銀明翠 銀座  評価点数：3.37点  レビュー件数：34 .   取得時間：18.784258365631104
# 79→店名：東京 今井屋本店  評価点数：3.55点  レビュー件数：144 .   取得時間：21.55589723587036
# 80→店名：すし縁  評価点数：3.54点  レビュー件数：77 .   取得時間：21.495274305343628
# 81→店名：オイスターバー&ワイン BELON 銀座  評価点数：3.44点  レビュー件数：48 .   取得時間：26.64757752418518
# 82→店名：しゃぶしゃぶ　すき鍋　おもき 銀座店  評価点数：3.30点  レビュー件数：95 .   取得時間：23.599725008010864
# 83→店名：塊 -KATAMARI- ミートバル 銀座  評価点数：3.25点  レビュー件数：56 .   取得時間：20.603403091430664
# 84→店名：京都 瓢喜 京橋店  評価点数：3.21点  レビュー件数：53 .   取得時間：20.40669298171997
# 85→店名：リストランテ･ヒロ・チェントロ 丸ビル店  評価点数：3.72点  レビュー件数：268 .   取得時間：23.479959726333618
# 86→店名：鮨たかや  評価点数：3.64点  レビュー件数：47 .   取得時間：20.36170983314514
# 87→店名：GRANBLANC  評価点数：3.36点  レビュー件数：63 .   取得時間：23.481579542160034
# 88→店名：小割烹 おはし 銀座  評価点数：3.41点  レビュー件数：43 .   取得時間：21.224125862121582
# 89→店名：PLUSTOKYO ROOFTOP  評価点数：-点  評価がないため処理対象外
# 89→店名：ラムしゃぶ 金の目 銀座本店  評価点数：3.58点  レビュー件数：140 .   取得時間：21.007540225982666
# 90→店名：PLUSTOKYO  評価点数：3.18点  レビュー件数：10 .   取得時間：10.132454633712769
# 91→店名：個室居酒屋 鳥助 有楽町店  評価点数：-点  評価がないため処理対象外
# 91→店名：アルカナ 東京  評価点数：3.57点  レビュー件数：102 .   取得時間：21.807178735733032
# 92→店名：花大根  評価点数：3.45点  レビュー件数：81 .   取得時間：22.659749746322632
# 93→店名：プーケットオリエンタル  評価点数：3.41点  レビュー件数：88 .   取得時間：18.891613721847534
# 94→店名：銀座 水炊きと焼き鳥 笹二  評価点数：3.25点  レビュー件数：45 .   取得時間：18.977709770202637
# 95→店名：アクアリウムダイニング銀座ライム  評価点数：3.47点  レビュー件数：129 .   取得時間：21.303608655929565
# 96→店名：鉄板焼　銀明翠 銀座  評価点数：3.37点  レビュー件数：34 .   取得時間：19.009469270706177
# 97→店名：東京 今井屋本店  評価点数：3.55点  レビュー件数：144 .   取得時間：20.43944811820984
# 98→店名：すし縁  評価点数：3.54点  レビュー件数：77 .   取得時間：23.266611099243164
# 99→店名：オイスターバー&ワイン BELON 銀座  評価点数：3.44点  レビュー件数：48 .   取得時間：20.476272344589233
# 100→店名：しゃぶしゃぶ　すき鍋　おもき 銀座店  評価点数：3.30点  レビュー件数：95 .   取得時間：21.624778985977173
# 101→店名：塊 -KATAMARI- ミートバル 銀座  評価点数：3.25点  レビュー件数：56 .   取得時間：20.352409601211548
# 102→店名：京都 瓢喜 京橋店  評価点数：3.21点  レビュー件数：53 .   取得時間：21.479223012924194
# 103→店名：リストランテ･ヒロ・チェントロ 丸ビル店  評価点数：3.72点  レビュー件数：268 .   取得時間：26.086952209472656
# 104→店名：鮨たかや  評価点数：3.64点  レビュー件数：47 .   取得時間：19.903505086898804
# 105→店名：GRANBLANC  評価点数：3.36点  レビュー件数：63 .   取得時間：20.098238468170166
# 106→店名：小割烹 おはし 銀座  評価点数：3.41点  レビュー件数：43 .   取得時間：21.34004044532776
# 107→店名：PLUSTOKYO ROOFTOP  評価点数：-点  評価がないため処理対象外
# 107→店名：ラムしゃぶ 金の目 銀座本店  評価点数：3.58点  レビュー件数：140 .   取得時間：20.28932499885559
# 108→店名：PLUSTOKYO  評価点数：3.18点  レビュー件数：10 .   取得時間：9.904892444610596
# 109→店名：個室居酒屋 鳥助 有楽町店  評価点数：-点  評価がないため処理対象外
# 1→店名：ピッツェリア レジスタ  評価点数：3.10点  レビュー件数：8 .   取得時間：10.882201433181763
# 2→店名：アクイロット  評価点数：3.39点  レビュー件数：28 .   取得時間：18.250637531280518
# 3→店名：安安 日吉店  評価点数：-点  評価がないため処理対象外
# 3→店名：ホアホア  評価点数：3.47点  レビュー件数：50 .   取得時間：19.83348298072815
# 4→店名：イチジク  評価点数：3.07点  レビュー件数：4 .   取得時間：5.0950891971588135
# 5→店名：アジアンビストロ Dai 日吉店  評価点数：3.51点  レビュー件数：72 .   取得時間：19.258784770965576
# 6→店名：鮨・酒・肴 杉玉  日吉  評価点数：3.06点  レビュー件数：3 .   取得時間：4.149723529815674
# 7→店名：遊ZEN たつ吉  評価点数：3.35点  レビュー件数：22 .   取得時間：20.50426197052002
# 8→店名：ROCCOMAN 日吉店  評価点数：3.43点  レビュー件数：30 .   取得時間：18.345566034317017
# 9→店名：金魚  評価点数：3.32点  レビュー件数：12 .   取得時間：11.831744909286499
# 10→店名：和IN場MARU  評価点数：3.09点  レビュー件数：10 .   取得時間：10.044402599334717
# 11→店名：やきとり家すみれ 日吉店  評価点数：3.06点  レビュー件数：4 .   取得時間：5.256078243255615
# 12→店名：日吉 金魚 Bettei  評価点数：3.06点  レビュー件数：3 .   取得時間：3.706632137298584
# 13→店名：サカバ 日吉MARU  評価点数：3.09点  レビュー件数：11 .   取得時間：10.23433518409729
# 14→店名：日吉酒場  評価点数：-点  評価がないため処理対象外
# 14→店名：龍華  評価点数：3.51点  レビュー件数：65 .   取得時間：21.142870903015137
# 15→店名：飯場 松の葉  評価点数：3.18点  レビュー件数：8 .   取得時間：7.690680265426636
# 16→店名：健康中華 青蓮 日吉店  評価点数：3.04点  レビュー件数：12 .   取得時間：11.201338768005371
# 17→店名：エスプレッソ・アメリカーノ 東急日吉店  評価点数：3.18点  レビュー件数：22 .   取得時間：17.624532461166382
# 18→店名：極楽汁麺 らすた  評価点数：3.59点  レビュー件数：242 .   取得時間：19.876161575317383
# 19→店名：ピッツェリア レジスタ  評価点数：3.10点  レビュー件数：8 .   取得時間：8.277488231658936
# 20→店名：アクイロット  評価点数：3.39点  レビュー件数：28 .   取得時間：20.915410041809082
# 21→店名：安安 日吉店  評価点数：-点  評価がないため処理対象外
# 21→店名：ホアホア  評価点数：3.47点  レビュー件数：50 .   取得時間：19.944380521774292
# 22→店名：イチジク  評価点数：3.07点  レビュー件数：4 .   取得時間：5.006073474884033
# 23→店名：アジアンビストロ Dai 日吉店  評価点数：3.51点  レビュー件数：72 .   取得時間：19.253061056137085
# 24→店名：鮨・酒・肴 杉玉  日吉  評価点数：3.06点  レビュー件数：3 .   取得時間：3.9141671657562256
# 25→店名：遊ZEN たつ吉  評価点数：3.35点  レビュー件数：22 .   取得時間：18.913613319396973
# 26→店名：ROCCOMAN 日吉店  評価点数：3.43点  レビュー件数：30 .   取得時間：21.148383855819702
# 27→店名：金魚  評価点数：3.32点  レビュー件数：12 .   取得時間：12.173642873764038
# 28→店名：和IN場MARU  評価点数：3.09点  レビュー件数：10 .   取得時間：10.140607357025146
# 29→店名：やきとり家すみれ 日吉店  評価点数：3.06点  レビュー件数：4 .   取得時間：5.568459987640381
# 30→店名：日吉 金魚 Bettei  評価点数：3.06点  レビュー件数：3 .   取得時間：4.2958314418792725
# 31→店名：サカバ 日吉MARU  評価点数：3.09点  レビュー件数：11 .   取得時間：10.561248302459717
# 32→店名：日吉酒場  評価点数：-点  評価がないため処理対象外
# 32→店名：龍華  評価点数：3.51点  レビュー件数：65 .   取得時間：20.25749182701111
# 33→店名：飯場 松の葉  評価点数：3.18点  レビュー件数：8 .   取得時間：7.441487073898315
# 34→店名：健康中華 青蓮 日吉店  評価点数：3.04点  レビュー件数：12 .   取得時間：13.137058019638062
# 35→店名：エスプレッソ・アメリカーノ 東急日吉店  評価点数：3.18点  レビュー件数：22 .   取得時間：18.10463571548462
# 36→店名：極楽汁麺 らすた  評価点数：3.59点  レビュー件数：242 .   取得時間：19.777639627456665
# 37→店名：ピッツェリア レジスタ  評価点数：3.10点  レビュー件数：8 .   取得時間：8.675958395004272
# 38→店名：アクイロット  評価点数：3.39点  レビュー件数：28 .   取得時間：18.05107045173645
# 39→店名：安安 日吉店  評価点数：-点  評価がないため処理対象外
# 39→店名：ホアホア  評価点数：3.47点  レビュー件数：50 .   取得時間：21.920787811279297
# 40→店名：イチジク  評価点数：3.07点  レビュー件数：4 .   取得時間：4.885929822921753
# 41→店名：アジアンビストロ Dai 日吉店  評価点数：3.51点  レビュー件数：72 .   取得時間：19.17326283454895
# 42→店名：鮨・酒・肴 杉玉  日吉  評価点数：3.06点  レビュー件数：3 .   取得時間：4.206554889678955
# 43→店名：遊ZEN たつ吉  評価点数：3.35点  レビュー件数：22 .   取得時間：18.98584532737732
# 44→店名：ROCCOMAN 日吉店  評価点数：3.43点  レビュー件数：30 .   取得時間：18.07347846031189
# 45→店名：金魚  評価点数：3.32点  レビュー件数：12 .   取得時間：11.710453271865845
# 46→店名：和IN場MARU  評価点数：3.09点  レビュー件数：10 .   取得時間：10.254021406173706
# 47→店名：やきとり家すみれ 日吉店  評価点数：3.06点  レビュー件数：4 .   取得時間：6.638607501983643
# 48→店名：日吉 金魚 Bettei  評価点数：3.06点  レビュー件数：3 .   取得時間：3.84230637550354
# 49→店名：サカバ 日吉MARU  評価点数：3.09点  レビュー件数：11 .   取得時間：10.660342693328857
# 50→店名：日吉酒場  評価点数：-点  評価がないため処理対象外
# 50→店名：龍華  評価点数：3.51点  レビュー件数：65 .   取得時間：20.67644429206848
# 51→店名：飯場 松の葉  評価点数：3.18点  レビュー件数：8 .   取得時間：7.675136566162109
# 52→店名：健康中華 青蓮 日吉店  評価点数：3.04点  レビュー件数：12 .   取得時間：10.972841739654541
# 53→店名：エスプレッソ・アメリカーノ 東急日吉店  評価点数：3.18点  レビュー件数：22 .   取得時間：17.23426866531372
# 54→店名：極楽汁麺 らすた  評価点数：3.59点  レビュー件数：242 .   取得時間：21.426554441452026
# 55→店名：ピッツェリア レジスタ  評価点数：3.10点  レビュー件数：8 .   取得時間：8.38025951385498
# 56→店名：アクイロット  評価点数：3.39点  レビュー件数：28 .   取得時間：18.739549160003662
# 57→店名：安安 日吉店  評価点数：-点  評価がないため処理対象外
# 57→店名：ホアホア  評価点数：3.47点  レビュー件数：50 .   取得時間：19.646049976348877
# 58→店名：イチジク  評価点数：3.07点  レビュー件数：4 .   取得時間：4.598152160644531
# 59→店名：アジアンビストロ Dai 日吉店  評価点数：3.51点  レビュー件数：72 .   取得時間：19.807411909103394
# 60→店名：鮨・酒・肴 杉玉  日吉  評価点数：3.06点  レビュー件数：3 .   取得時間：3.805166006088257
# 61→店名：遊ZEN たつ吉  評価点数：3.35点  レビュー件数：22 .   取得時間：20.31127953529358
# 62→店名：ROCCOMAN 日吉店  評価点数：3.43点  レビュー件数：30 .   取得時間：18.156314611434937
# 63→店名：金魚  評価点数：3.32点  レビュー件数：12 .   取得時間：12.051997900009155
# 64→店名：和IN場MARU  評価点数：3.09点  レビュー件数：10 .   取得時間：10.237245321273804
# 65→店名：やきとり家すみれ 日吉店  評価点数：3.06点  レビュー件数：4 .   取得時間：4.821479797363281
# 66→店名：日吉 金魚 Bettei  評価点数：3.06点  レビュー件数：3 .   取得時間：4.191465854644775
# 67→店名：サカバ 日吉MARU  評価点数：3.09点  レビュー件数：11 .   取得時間：10.725817203521729
# 68→店名：日吉酒場  評価点数：-点  評価がないため処理対象外
# 68→店名：龍華  評価点数：3.51点  レビュー件数：65 .   取得時間：20.355785131454468
# 69→店名：飯場 松の葉  評価点数：3.18点  レビュー件数：8 .   取得時間：7.481367588043213
# 70→店名：健康中華 青蓮 日吉店  評価点数：3.04点  レビュー件数：12 .   取得時間：13.072052001953125
# 71→店名：エスプレッソ・アメリカーノ 東急日吉店  評価点数：3.18点  レビュー件数：22 .   取得時間：18.371137142181396
# 72→店名：極楽汁麺 らすた  評価点数：3.59点  レビュー件数：242 .   取得時間：20.709547758102417
# 73→店名：ピッツェリア レジスタ  評価点数：3.10点  レビュー件数：8 .   取得時間：7.981403827667236
# 74→店名：アクイロット  評価点数：3.39点  レビュー件数：28 .   取得時間：18.123253345489502
# 75→店名：安安 日吉店  評価点数：-点  評価がないため処理対象外
# 75→店名：ホアホア  評価点数：3.47点  レビュー件数：50 .   取得時間：20.53127145767212
# 76→店名：イチジク  評価点数：3.07点  レビュー件数：4 .   取得時間：7.225698471069336
# 77→店名：アジアンビストロ Dai 日吉店  評価点数：3.51点  レビュー件数：72 .   取得時間：19.191636562347412
# 78→店名：鮨・酒・肴 杉玉  日吉  評価点数：3.06点  レビュー件数：3 .   取得時間：3.7549080848693848
# 79→店名：遊ZEN たつ吉  評価点数：3.35点  レビュー件数：22 .   取得時間：19.433714151382446
# 80→店名：ROCCOMAN 日吉店  評価点数：3.43点  レビュー件数：30 .   取得時間：17.912366151809692
# 81→店名：金魚  評価点数：3.32点  レビュー件数：12 .   取得時間：12.281742095947266
# 82→店名：和IN場MARU  評価点数：3.09点  レビュー件数：10 .   取得時間：10.711677074432373
# 83→店名：やきとり家すみれ 日吉店  評価点数：3.06点  レビュー件数：4 .   取得時間：5.224859237670898
# 84→店名：日吉 金魚 Bettei  評価点数：3.06点  レビュー件数：3 .   取得時間：3.9716544151306152
# 85→店名：サカバ 日吉MARU  評価点数：3.09点  レビュー件数：11 .   取得時間：13.00469970703125
# 86→店名：日吉酒場  評価点数：-点  評価がないため処理対象外
# 86→店名：龍華  評価点数：3.51点  レビュー件数：65 .   取得時間：19.610310316085815
# 87→店名：飯場 松の葉  評価点数：3.18点  レビュー件数：8 .   取得時間：7.64532208442688
# 88→店名：健康中華 青蓮 日吉店  評価点数：3.04点  レビュー件数：12 .   取得時間：11.612611770629883
# 89→店名：エスプレッソ・アメリカーノ 東急日吉店  評価点数：3.18点  レビュー件数：22 .   取得時間：17.325650453567505
# 90→店名：極楽汁麺 らすた  評価点数：3.59点  レビュー件数：242 .   取得時間：20.426047801971436
# 91→店名：ピッツェリア レジスタ  評価点数：3.10点  レビュー件数：8 .   取得時間：8.209014892578125
# 92→店名：アクイロット  評価点数：3.39点  レビュー件数：28 .   取得時間：20.12751007080078
# 93→店名：安安 日吉店  評価点数：-点  評価がないため処理対象外
# 93→店名：ホアホア  評価点数：3.47点  レビュー件数：50 .   取得時間：18.871188640594482
# 94→店名：イチジク  評価点数：3.07点  レビュー件数：4 .   取得時間：4.680229187011719
# 95→店名：アジアンビストロ Dai 日吉店  評価点数：3.51点  レビュー件数：72 .   取得時間：19.180617809295654
# 96→店名：鮨・酒・肴 杉玉  日吉  評価点数：3.06点  レビュー件数：3 .   取得時間：4.198612451553345
# 97→店名：遊ZEN たつ吉  評価点数：3.35点  レビュー件数：22 .   取得時間：20.17550230026245
# 98→店名：ROCCOMAN 日吉店  評価点数：3.43点  レビュー件数：30 .   取得時間：18.697384119033813
# 99→店名：金魚  評価点数：3.32点  レビュー件数：12 .   取得時間：13.557595491409302
# 100→店名：和IN場MARU  評価点数：3.09点  レビュー件数：10 .   取得時間：9.744733333587646
# 101→店名：やきとり家すみれ 日吉店  評価点数：3.06点  レビュー件数：4 .   取得時間：5.247189044952393
# 102→店名：日吉 金魚 Bettei  評価点数：3.06点  レビュー件数：3 .   取得時間：3.9678456783294678
# 103→店名：サカバ 日吉MARU  評価点数：3.09点  レビュー件数：11 .   取得時間：10.365224838256836
# 104→店名：日吉酒場  評価点数：-点  評価がないため処理対象外
# 104→店名：龍華  評価点数：3.51点  レビュー件数：65 .   取得時間：20.27513313293457
# 105→店名：飯場 松の葉  評価点数：3.18点  レビュー件数：8 .   取得時間：7.211153745651245
# 106→店名：健康中華 青蓮 日吉店  評価点数：3.04点  レビュー件数：12 .   取得時間：11.435672283172607
# 107→店名：エスプレッソ・アメリカーノ 東急日吉店  評価点数：3.18点  レビュー件数：22 .   取得時間：17.474270582199097
# 108→店名：極楽汁麺 らすた  評価点数：3.59点  レビュー件数：242 .   取得時間：21.3793466091156
